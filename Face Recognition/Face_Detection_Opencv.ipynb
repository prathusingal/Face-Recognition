# %%
#pip install opencv-python
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'c:\users\prathu' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import sys

# %%
img = plt.imread("group-photo1.png")

# %%
img.shape
# Out:
# (385, 600, 3)

# %%
plt.imshow(img)

# %%
detector = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-tts2sm8m\opencv\modules\core\src\persistence.cpp:717: error: (-49:Unknown error code -49) Input file is invalid in function 'cv::FileStorage::Impl::open'
#
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-57-89b3c89e6824> in <module>
# ----> 1 detector = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")
#
# SystemError: <class 'cv2.CascadeClassifier'> returned a result with an error set

# %%
detector
# Out:
# <CascadeClassifier 06282130>

# %%
faces = detector.detectMultiScale(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-48-83d29b2ef7f2> in <module>
# ----> 1 faces = detector.detectMultiScale(img)
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-tts2sm8m\opencv\modules\objdetect\src\cascadedetect.cpp:1389: error: (-215:Assertion failed) scaleFactor > 1 && _image.depth() == CV_8U in function 'cv::CascadeClassifierImpl::detectMultiScale'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-32d0506b73d3> in <module>
# ----> 1 faces = faceCascade.detectMultiScale(
#       2     gray,
#       3     scaleFactor=1.1,
#       4     minNeighbors=5,
#       5     minSize=(30, 30),
#
# NameError: name 'faceCascade' is not defined

# %%
faces
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c184e6e085ff> in <module>
# ----> 1 faces
#
# NameError: name 'faces' is not defined

# %%
for face in faces:
    x,y, w, h = face
    
    img = cv2.rectangle(img, (x,y), (x+w, y+h), (255,255,255), 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f247358e61b1> in <module>
# ----> 1 for face in faces:
#       2     x,y, w, h = face
#       3
#       4     img = cv2.rectangle(img, (x,y), (x+w, y+h), (255,255,255), 3)
#       5
#
# NameError: name 'faces' is not defined

# %%
# x,y,w,h = faces[0]

# %%
# modified_img = cv2.rectangle(img, (x,y), (x+w, y+h), (255,255,255), 2)

# %%
# plt.imshow(modified_img)

# %%
plt.imshow(img)
